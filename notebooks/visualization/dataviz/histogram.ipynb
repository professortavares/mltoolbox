# %% [markdown]
# # Notebook responsible for displaying a histogram from randomly generated data

# %%
import numpy as np
import pandas as pd

from mltoolbox.visualization import DataViz

# %% [markdown]
# ## Generates a set of 1000 random numbers

# %%
mu, sigma = 0, 1 # mean and standard deviation
data = np.random.normal(mu, sigma, 1000)

d = {
    'random_numbers':data
}

df = pd.DataFrame(d)

# %%
df
# Out:
#      random_numbers
# 0         -0.028967
# 1         -0.428319
# 2         -0.103723
# 3          0.391142
# 4         -0.195566
# ..              ...
# 995        0.793470
# 996        0.161273
# 997        0.666154
# 998       -0.572568
# 999        0.507710
#
# [1000 rows x 1 columns]

# %% [markdown]
# ## Creates an instance of DataViz and plots the histogram

# %%
dv = DataViz()
dv.plot_histogram(df=df, column='random_numbers')
